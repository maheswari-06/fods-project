# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('movies_1980_2020_30k.csv')
print(df.head())
# Out:
#                  Title         Director        Genre Release Date  Duration  \
# 0  Key entire popular.   Anthony Becker       Horror   1981-05-12       102
# 1  Gun husband reveal.  William Johnson  Documentary   2016-06-13        92
# 2         Crime cover.           Amy Le        Drama   1988-03-22       144
# 3           Challenge.  Andrea Martinez      Romance   2013-04-01       161
# 4         Close study.  Michael Rodgers      Fantasy   2012-10-18       177
#
#    Rating
# 0     6.8
# 1     7.6
# 2     5.5
# 3     2.0
# 4     3.7

# %%
features=df.columns
print(features)
# Out:
# Index(['Title', 'Director', 'Genre', 'Release Date', 'Duration', 'Rating'], dtype='object')

# %%
datatypes=df.dtypes
print(datatypes)
# Out:
# Title            object
# Director         object
# Genre            object
# Release Date     object
# Duration          int64
# Rating          float64
# dtype: object

# %%
describe=df.describe()
print(describe)
# Out:
#            Duration        Rating
# count  30000.000000  30000.000000
# mean     120.131033      5.519867
# std       34.981221      2.591138
# min       60.000000      1.000000
# 25%       90.000000      3.300000
# 50%      120.000000      5.500000
# 75%      150.000000      7.700000
# max      180.000000     10.000000

# %%
x=np.array(df['Title'])
y=np.array(df['Release Date'])

# %%
plt.plot(x,y)
plt.xlabel('Title')
plt.ylabel('Release Date')
plt.show()
